# %% [markdown]
# # Explore here

# %%
#import relevant packages
import pandas as pd
from sqlalchemy import create_engine
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
#load datasets
url_movies = 'https://raw.githubusercontent.com/4GeeksAcademy/k-nearest-neighbors-project-tutorial/main/tmdb_5000_movies.csv'
url_credits = 'https://raw.githubusercontent.com/4GeeksAcademy/k-nearest-neighbors-project-tutorial/main/tmdb_5000_credits.csv'

movies = pd.read_csv(url_movies)
credits = pd.read_csv(url_credits)

movies.columns, credits.columns
# Out:
# (Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#         'original_title', 'overview', 'popularity', 'production_companies',
#         'production_countries', 'release_date', 'revenue', 'runtime',
#         'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#         'vote_count'],
#        dtype='object'),
#  Index(['movie_id', 'title', 'cast', 'crew'], dtype='object'))

# %%
#create connection to postgresql database
engine = create_engine('postgresql://gitpod:admin@localhost:5432/knn_database')

# %%
#write dataframes to database
movies.to_sql('movies', engine, if_exists='replace', index=False)
credits.to_sql('credits', engine, if_exists='replace', index=False)
# Out:
# 803

# %%
#join both tables using sql query and store in new dataframe
df = pd.read_sql_query('SELECT m.id, m.title, m.overview, m.genres, m.keywords, c.cast, c.crew FROM movies AS m JOIN credits AS c ON m.title = c.title', engine)
df
# Out:
#           id                       title  \
# 0      10481              102 Dalmatians
# 1     333371         10 Cloverfield Lane
# 2     345003       10 Days in a Madhouse
# 3       4951  10 Things I Hate About You
# 4      13197                 10th & Wolf
# ...      ...                         ...
# 4804    9398                   Zoolander
# 4805  329833                 Zoolander 2
# 4806   14113                        Zoom
# 4807  277519                     Z Storm
# 4808  185567                        Zulu
#
#                                                overview  \
# 0     Get ready for a howling good time as an all ne...
# 1     After a car accident, Michelle awakens to find...
# 2     Nellie Bly, a 23 year-old reporter for Joseph ...
# 3     Bianca, a tenth grader, has never gone on a da...
# 4     A former street tough returns to his Philadelp...
# ...                                                 ...
# 4804  Clear the runway for Derek Zoolander, VH1's th...
# 4805  Derek and Hansel are modelling again when an o...
# 4806  Jack Shepard is an out-of-shape auto shop owne...
# 4807  This is a story about the biggest financial fr...
# 4808  As a child, Ali Neuman narrowly escaped being ...
#
#                                                  genres  \
# 0     [{"id": 35, "name": "Comedy"}, {"id": 10751, "...
# 1     [{"id": 53, "name": "Thriller"}, {"id": 878, "...
# 2                         [{"id": 18, "name": "Drama"}]
# 3     [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...                                                 ...
# 4804                     [{"id": 35, "name": "Comedy"}]
# 4805                     [{"id": 35, "name": "Comedy"}]
# 4806  [{"id": 10751, "name": "Family"}, {"id": 14, "...
# 4807  [{"id": 80, "name": "Crime"}, {"id": 53, "name...
# 4808  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
#
#                                                keywords  \
# 0     [{"id": 212, "name": "london england"}, {"id":...
# 1     [{"id": 1930, "name": "kidnapping"}, {"id": 23...
# 2     [{"id": 1568, "name": "undercover"}, {"id": 49...
# 3     [{"id": 497, "name": "shakespeare"}, {"id": 59...
# 4     [{"id": 1568, "name": "undercover"}, {"id": 10...
# ...                                                 ...
# 4804  [{"id": 167193, "name": "male model"}, {"id": ...
# 4805  [{"id": 6241, "name": "stupidity"}, {"id": 966...
# 4806  [{"id": 9715, "name": "superhero"}, {"id": 996...
# 4807                                                 []
# 4808                                                 []
#
#                                                    cast  \
# 0     [{"cast_id": 1, "character": "Cruella de Vil",...
# 1     [{"cast_id": 2, "character": "Michelle", "cred...
# 2     [{"cast_id": 2, "character": "Nellie Bly", "cr...
# 3     [{"cast_id": 2, "character": "Patrick Verona",...
# 4     [{"cast_id": 1, "character": "Tommy", "credit_...
# ...                                                 ...
# 4804  [{"cast_id": 1, "character": "Derek Zoolander"...
# 4805  [{"cast_id": 0, "character": "Derek Zoolander"...
# 4806  [{"cast_id": 1, "character": "Jack Sheppard", ...
# 4807  [{"cast_id": 0, "character": "William Luk", "c...
# 4808  [{"cast_id": 2, "character": "Brian Epkeen", "...
#
#                                                    crew
# 0     [{"credit_id": "5539fe5e9251413f5a00359b", "de...
# 1     [{"credit_id": "57627624c3a3680682000872", "de...
# 2     [{"credit_id": "594efa1fc3a36832650455ff", "de...
# 3     [{"credit_id": "52fe43e6c3a36847f807731d", "de...
# 4     [{"credit_id": "52fe454d9251416c75051e59", "de...
# ...                                                 ...
# 4804  [{"credit_id": "556f8417925141326c0008cb", "de...
# 4805  [{"credit_id": "54ff0d5e9251410e56001a13", "de...
# 4806  [{"credit_id": "573133109251414868000f72", "de...
# 4807  [{"credit_id": "53ad797c0e0a265975002134", "de...
# 4808  [{"credit_id": "553f81bec3a3685c650033a2", "de...
#
# [4809 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# id          0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
#extract and reformat columns containing json data
#genres and keywords
df['genres'] = df['genres'].apply(lambda x: [i['name'] for i in eval(x)]) #extract names
df['keywords'] = df['keywords'].apply(lambda x: [i['name'] for i in eval(x)]) #extract names

#cast
df['cast'] = df['cast'].apply(lambda x: [i['name'] for i in eval(x)]) #extract names
df['cast'] = df['cast'].apply(lambda x: x[:3]) #reduce cast names to 3

#crew
df['crew'] = df['crew'].apply(lambda x: [i['name'] for i in eval(x) if i['job'] == 'Director']) #extract director name

#overview
df['overview'] = df['overview'].apply(lambda x: [x] if x != None else [' ']) #convert to list

#df = df[['movie_id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew']]
df.head()
# Out:
#        id                       title  \
# 0   10481              102 Dalmatians
# 1  333371         10 Cloverfield Lane
# 2  345003       10 Days in a Madhouse
# 3    4951  10 Things I Hate About You
# 4   13197                 10th & Wolf
#
#                                             overview  \
# 0  [Get ready for a howling good time as an all n...
# 1  [After a car accident, Michelle awakens to fin...
# 2  [Nellie Bly, a 23 year-old reporter for Joseph...
# 3  [Bianca, a tenth grader, has never gone on a d...
# 4  [A former street tough returns to his Philadel...
#
#                                       genres  \
# 0                           [Comedy, Family]
# 1         [Thriller, Science Fiction, Drama]
# 2                                    [Drama]
# 3                   [Comedy, Romance, Drama]
# 4  [Action, Crime, Drama, Mystery, Thriller]
#
#                                             keywords  \
# 0  [london england, prison, release from prison, ...
# 1  [kidnapping, bunker, paranoia, basement, survi...
# 2              [undercover, insane asylum, reporter]
# 3  [shakespeare, sister, high school, cannabis, d...
# 4         [undercover, mafia, mobster, crime family]
#
#                                                 cast                crew
# 0          [Glenn Close, Ioan Gruffudd, Alice Evans]        [Kevin Lima]
# 1  [Mary Elizabeth Winstead, John Goodman, John G...  [Dan Trachtenberg]
# 2  [Caroline Barry, Christopher Lambert, Kelly Le...     [Timothy Hines]
# 3  [Heath Ledger, Julia Stiles, Joseph Gordon-Lev...        [Gil Junger]
# 4          [James Marsden, Brian Dennehy, Leo Rossi]    [Robert Moresco]

# %%
#remove spaces between words
cols = ['genres', 'cast', 'crew', 'keywords']
for col in cols:
    df[col] = df[col].apply(lambda x: [i.replace(' ', '') for i in x])

df
# Out:
#           id                       title  \
# 0      10481              102 Dalmatians
# 1     333371         10 Cloverfield Lane
# 2     345003       10 Days in a Madhouse
# 3       4951  10 Things I Hate About You
# 4      13197                 10th & Wolf
# ...      ...                         ...
# 4804    9398                   Zoolander
# 4805  329833                 Zoolander 2
# 4806   14113                        Zoom
# 4807  277519                     Z Storm
# 4808  185567                        Zulu
#
#                                                overview  \
# 0     [Get ready for a howling good time as an all n...
# 1     [After a car accident, Michelle awakens to fin...
# 2     [Nellie Bly, a 23 year-old reporter for Joseph...
# 3     [Bianca, a tenth grader, has never gone on a d...
# 4     [A former street tough returns to his Philadel...
# ...                                                 ...
# 4804  [Clear the runway for Derek Zoolander, VH1's t...
# 4805  [Derek and Hansel are modelling again when an ...
# 4806  [Jack Shepard is an out-of-shape auto shop own...
# 4807  [This is a story about the biggest financial f...
# 4808  [As a child, Ali Neuman narrowly escaped being...
#
#                                          genres  \
# 0                              [Comedy, Family]
# 1             [Thriller, ScienceFiction, Drama]
# 2                                       [Drama]
# 3                      [Comedy, Romance, Drama]
# 4     [Action, Crime, Drama, Mystery, Thriller]
# ...                                         ...
# 4804                                   [Comedy]
# 4805                                   [Comedy]
# 4806                  [Family, Fantasy, Comedy]
# 4807                          [Crime, Thriller]
# 4808                   [Crime, Drama, Thriller]
#
#                                                keywords  \
# 0     [londonengland, prison, releasefromprison, wom...
# 1     [kidnapping, bunker, paranoia, basement, survi...
# 2                  [undercover, insaneasylum, reporter]
# 3     [shakespeare, sister, highschool, cannabis, de...
# 4             [undercover, mafia, mobster, crimefamily]
# ...                                                 ...
# 4804  [malemodel, timemagazine, fashionshow, fashion...
# 4805  [stupidity, sequel, fashion, malemodel, fashio...
# 4806                         [superhero, kidsandfamily]
# 4807                                                 []
# 4808                                                 []
#
#                                                    cast               crew
# 0                [GlennClose, IoanGruffudd, AliceEvans]        [KevinLima]
# 1     [MaryElizabethWinstead, JohnGoodman, JohnGalla...  [DanTrachtenberg]
# 2     [CarolineBarry, ChristopherLambert, KellyLeBrock]     [TimothyHines]
# 3       [HeathLedger, JuliaStiles, JosephGordon-Levitt]        [GilJunger]
# 4                [JamesMarsden, BrianDennehy, LeoRossi]    [RobertMoresco]
# ...                                                 ...                ...
# 4804          [BenStiller, OwenWilson, ChristineTaylor]       [BenStiller]
# 4805              [BenStiller, OwenWilson, WillFerrell]       [BenStiller]
# 4806               [TimAllen, CourteneyCox, ChevyChase]      [PeterHewitt]
# 4807             [LouisKoo, GordonLamKa-Tung, DadaChan]         [DavidLam]
# 4808         [OrlandoBloom, ForestWhitaker, ConradKemp]      [JérômeSalle]
#
# [4809 rows x 7 columns]

# %%
#create tags columns
df['tags'] = df['overview'] + df['genres'] + df['keywords'] + df['cast'] + df['crew']
df['tags']
# Out:
# 0       [Get ready for a howling good time as an all n...
# 1       [After a car accident, Michelle awakens to fin...
# 2       [Nellie Bly, a 23 year-old reporter for Joseph...
# 3       [Bianca, a tenth grader, has never gone on a d...
# 4       [A former street tough returns to his Philadel...
#                               ...
# 4804    [Clear the runway for Derek Zoolander, VH1's t...
# 4805    [Derek and Hansel are modelling again when an ...
# 4806    [Jack Shepard is an out-of-shape auto shop own...
# 4807    [This is a story about the biggest financial f...
# 4808    [As a child, Ali Neuman narrowly escaped being...
# Name: tags, Length: 4809, dtype: object

# %%
#define X and y
for i in range(len(df['tags'])):
    df['tags'][i] = ' '.join(df['tags'][i])

df['tags']
# Out:
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# ...
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# /tmp/ipykernel_5774/532404903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'][i] = ' '.join(df['tags'][i])
# 0       Get ready for a howling good time as an all ne...
# 1       After a car accident, Michelle awakens to find...
# 2       Nellie Bly, a 23 year-old reporter for Joseph ...
# 3       Bianca, a tenth grader, has never gone on a da...
# 4       A former street tough returns to his Philadelp...
#                               ...
# 4804    Clear the runway for Derek Zoolander, VH1's th...
# 4805    Derek and Hansel are modelling again when an o...
# 4806    Jack Shepard is an out-of-shape auto shop owne...
# 4807    This is a story about the biggest financial fr...
# 4808    As a child, Ali Neuman narrowly escaped being ...
# Name: tags, Length: 4809, dtype: object

# %%
#vectorize tags
vec_model = CountVectorizer(stop_words = "english")
tags_vectorized = vec_model.fit_transform(df['tags'])

tags_vectorized
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 190091 stored elements and shape (4809, 35557)>

# %%
similarity = cosine_similarity(tags_vectorized)

# %%
#similarity function
def recommend(movie):
    movie_index = df[df["title"] == movie].index[0]
    distances = similarity[movie_index]
    movie_list = sorted(list(enumerate(distances)), reverse = True , key = lambda x: x[1])[1:6]
    
    for i in movie_list:
        print(df.iloc[i[0]].title)

# %%
#try function
recommend('American History X')
# Out:
# Out of the Furnace
# Penitentiary
# Mean Machine
# Bronson
# Fortress
